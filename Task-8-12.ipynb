# %% [markdown]
# Периметр описанной около круга трапеции равен 24 см. Определить среднюю линию трапеции.

# %% [markdown]
# ![Task-8-12](Task-8-12.png)

# %%
#P:AB+BC+CD+AD;
#AB+CD=AD+BC;
#CD+AB=12
#BC+AD=12
from sympy import Eq
from sympy import solve
from sympy import symbols
from sympy import sqrt

p = 24; s1 = p / 2; s2 = p / 2;
c = s1 / 2
print("c =", c)
# Out:
# c = 6.0
